# %%
'''
import scipy.cluster.hierarchy as shc
from sklearn.cluster import AgglomerativeClustering

dendro = shc.dendrogram(shc.linkage(X, method="ward"))

hc = AgglomerativeClustering(n_clusters=5, linkage='ward') 
y_pred = hc.fit_predict(X)

====================================================================================
hierarchical clustering -> unsupervised clustering algo -> scatter
'''
# Out:
# '\nimport scipy.cluster.hierarchy as shc\nfrom sklearn.cluster import AgglomerativeClustering\n\ndendro = shc.dendrogram(shc.linkage(X, method="ward"))\n\nhc = AgglomerativeClustering(n_clusters=5, linkage=\'ward\') \ny_pred = hc.fit_predict(X)\n\n====================================================================================\nhierarchical clustering -> unsupervised clustering algo -> scatter\n'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.cluster.hierarchy as shc
from sklearn.cluster import AgglomerativeClustering

def plot_clusters_hierarchical(X, y_pred, title, x_label, y_label):
    plt.scatter(X[y_pred == 0, 0], X[y_pred == 0, 1], s=100, c='blue',   label='Cluster 1')
    plt.scatter(X[y_pred == 1, 0], X[y_pred == 1, 1], s=100, c='green',  label='Cluster 2')
    plt.scatter(X[y_pred == 2, 0], X[y_pred == 2, 1], s=100, c='red',    label='Cluster 3')
    plt.scatter(X[y_pred == 3, 0], X[y_pred == 3, 1], s=100, c='cyan',   label='Cluster 4')
    plt.scatter(X[y_pred == 4, 0], X[y_pred == 4, 1], s=100, c='magenta',label='Cluster 5')

    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.legend()
    plt.show()


# Step 1: Data Pre-processing
dataset = pd.read_csv('Mall_Customers_data.csv')
X = dataset.iloc[:, [3, 4]].values

# Step 2: Finding the optimal number of clusters using the Dendrogram
dendro = shc.dendrogram(shc.linkage(X, method="ward"))
plt.title ("Dendrogram Plot")
plt.ylabel("Euclidean Distances")
plt.xlabel("Customers")
plt.show()

# Step 3: Training the hierarchical clustering model
hc = AgglomerativeClustering(n_clusters=5, linkage='ward') 
y_pred = hc.fit_predict(X)

# Step 4: Visualizing the clusters
plot_clusters_hierarchical(X, y_pred, 'Clusters of customers', 'Annual Income (k$)', 'Spending Score (1-100)')
